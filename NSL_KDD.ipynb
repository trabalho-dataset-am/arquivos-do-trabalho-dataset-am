# %% [markdown]
# ![logoIC_UFF.jpg](data:image/jpeg;base64,...)
#
#
#
# ---
#
#
# # **Atividade com Dataset escolhido**
# **Alunos**:
# Augusto Parisot de Gusmão Neto e Marcelo Marques da Rocha

# %%
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
labels = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate',
'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count',
'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate',
'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class', 'desconhecido']

len(labels)
# Out:
# 43

# %%
nsl_kdd_train = pd.read_csv('/content/drive/MyDrive/KDDTrain+.csv', names=labels)
nsl_kdd_train.shape
# Out:
# (125973, 43)

# %%
nsl_kdd_train
# Out:
#         duration protocol_type  ...    class desconhecido
# 0              0           tcp  ...   normal           20
# 1              0           udp  ...   normal           15
# 2              0           tcp  ...  neptune           19
# 3              0           tcp  ...   normal           21
# 4              0           tcp  ...   normal           21
# ...          ...           ...  ...      ...          ...
# 125968         0           tcp  ...  neptune           20
# 125969         8           udp  ...   normal           21
# 125970         0           tcp  ...   normal           18
# 125971         0           tcp  ...  neptune           20
# 125972         0           tcp  ...   normal           21
#
# [125973 rows x 43 columns]

# %%
nsl_kdd_test = pd.read_csv('/content/drive/MyDrive/KDDTest+.csv', names=labels)
nsl_kdd_test.shape
# Out:
# (22544, 43)

# %%
nsl_kdd_test
# Out:
#        duration protocol_type  ...    class desconhecido
# 0             0           tcp  ...  neptune           21
# 1             0           tcp  ...  neptune           21
# 2             2           tcp  ...   normal           21
# 3             0          icmp  ...    saint           15
# 4             1           tcp  ...    mscan           11
# ...         ...           ...  ...      ...          ...
# 22539         0           tcp  ...   normal           21
# 22540         0           tcp  ...   normal           21
# 22541         0           tcp  ...     back           15
# 22542         0           udp  ...   normal           21
# 22543         0           tcp  ...    mscan           14
#
# [22544 rows x 43 columns]

# %%
# concatenando a base de treinamento com a base de teste
kdd_completo = pd.concat([nsl_kdd_train, nsl_kdd_test])
kdd_completo.shape
# Out:
# (148517, 43)

# %%
kdd_completo
# Out:
#        duration protocol_type  ...    class desconhecido
# 0             0           tcp  ...   normal           20
# 1             0           udp  ...   normal           15
# 2             0           tcp  ...  neptune           19
# 3             0           tcp  ...   normal           21
# 4             0           tcp  ...   normal           21
# ...         ...           ...  ...      ...          ...
# 22539         0           tcp  ...   normal           21
# 22540         0           tcp  ...   normal           21
# 22541         0           tcp  ...     back           15
# 22542         0           udp  ...   normal           21
# 22543         0           tcp  ...    mscan           14
#
# [148517 rows x 43 columns]

# %%
kdd_completo.describe()
# Out:
#             duration     src_bytes  ...  dst_host_srv_rerror_rate   desconhecido
# count  148517.000000  1.485170e+05  ...             148517.000000  148517.000000
# mean      276.779305  4.022795e+04  ...                  0.136397      19.278480
# std      2460.683131  5.409612e+06  ...                  0.335282       2.739757
# min         0.000000  0.000000e+00  ...                  0.000000       0.000000
# 25%         0.000000  0.000000e+00  ...                  0.000000      18.000000
# 50%         0.000000  4.400000e+01  ...                  0.000000      20.000000
# 75%         0.000000  2.780000e+02  ...                  0.000000      21.000000
# max     57715.000000  1.379964e+09  ...                  1.000000      21.000000
#
# [8 rows x 39 columns]

# %%
#observando os tipos dos atributos e se existe algum elemento null (NaN)
kdd_completo.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148517 entries, 0 to 22543
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
# ...

# %%
#sns.countplot(x='desconhecido', data=kdd_completo);
#sns.distplot(kdd_completo['desconhecido'], kde=False);
kdd_completo['desconhecido'].hist()

# %%
# verificando a distribuição dos eventos em class (normal e ataques)
plt.figure(figsize=(80,20))
sns.countplot(x='class', data=kdd_completo);

# %%
# o gráfico não ajuda nesse caso, já que são muito tipos de ataques e com frequeências muito distintas
# melhor contar usando uma representação tabular
qtd = kdd_completo['class'].value_counts()
print("Total de tipos de eventos no atributo class: ", len(qtd))
print("normal(sem ataque) e 39 tipos de ataque...\n")
print(qtd)
# Out:
# Total de tipos de eventos no atributo class:  40
# normal(sem ataque) e 39 tipos de ataque...
#
# normal             77054
# neptune            45871
# satan               4368
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# ...

# %%
#Observando a correlação entre os atributos
kdd_completo.corr()
# Out:
#                              duration  ...  desconhecido
# duration                     1.000000  ...     -0.126980
# src_bytes                    0.068959  ...     -0.017770
# dst_bytes                    0.034056  ...     -0.013567
# land                        -0.001651  ...     -0.026944
# wrong_fragment              -0.009616  ...     -0.130583
# urgent                       0.002426  ...     -0.044597
# hot                          0.000664  ...     -0.130702
# num_failed_logins            0.000525  ...     -0.152250
# logged_in                   -0.064474  ...      0.224275
# num_compromised              0.043998  ...     -0.004907
# root_shell                   0.046792  ...     -0.078046
# su_attempted                 0.087257  ...     -0.017357
# num_root                     0.046908  ...     -0.004013
# num_file_creations           0.083243  ...     -0.028504
# num_shells                  -0.000996  ...     -0.052143
# ...

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(kdd_completo.corr());

# %% [markdown]
# ##**Investigando a relação entre os tipos de ataque e os tipos de protocolos de rede**##
#
# * O gráfico a seguir nos mostra que a grande maioria dos tipos de ataque se aplicam sobre o protocolo tcp.

# %%
coluna = ['class', 'protocol_type']
kdd_classe = kdd_completo.filter(items=coluna)
sns.relplot(x="protocol_type", y="class", hue="protocol_type", style="protocol_type", data=kdd_classe);

# %%
#observando os atributos do tipo object 
plt.figure(figsize=(8, 5))
sns.countplot(x='flag', data=kdd_completo);

# %%
#observando os atributos do tipo object 
sns.countplot(x='protocol_type', data=kdd_completo);

# %%
# eliminando o atributo desconhecido
kdd_completo.drop('desconhecido', axis=1)
# Out:
#        duration protocol_type  ... dst_host_srv_rerror_rate    class
# 0             0           tcp  ...                     0.00   normal
# 1             0           udp  ...                     0.00   normal
# 2             0           tcp  ...                     0.00  neptune
# 3             0           tcp  ...                     0.01   normal
# 4             0           tcp  ...                     0.00   normal
# ...         ...           ...  ...                      ...      ...
# 22539         0           tcp  ...                     0.00   normal
# 22540         0           tcp  ...                     0.00   normal
# 22541         0           tcp  ...                     0.07     back
# 22542         0           udp  ...                     0.00   normal
# 22543         0           tcp  ...                     1.00    mscan
#
# [148517 rows x 42 columns]

# %%
# transformando o atributo class em 0 para normal e 1 para algum tipo de ataque
for linha in kdd_completo['class']:
  if linha == 'normal':
    kdd_completo[row['class']] = 0
  else:
    kdd_completo[row['class']] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-22adff66a1a9> in <module>()
#       2 for linha in kdd_completo['class']:
#       3   if linha == 'normal':
# ----> 4     kdd_completo[row['class']] = 0
#       5   else:
#       6     kdd_completo[row['class']] = 1
#
# NameError: name 'row' is not defined

# %%
# verificando o resultado
kdd_completo
# Out:
#        duration protocol_type  ... class desconhecido
# 0             0           tcp  ...     2           20
# 1             0           udp  ...     2           15
# 2             0           tcp  ...     2           19
# 3             0           tcp  ...     2           21
# 4             0           tcp  ...     2           21
# ...         ...           ...  ...   ...          ...
# 22539         0           tcp  ...     2           21
# 22540         0           tcp  ...     2           21
# 22541         0           tcp  ...     2           15
# 22542         0           udp  ...     2           21
# 22543         0           tcp  ...     2           14
#
# [148517 rows x 43 columns]

# %%
#kdd_completo.to_csv(r'/content/drive/MyDrive/NSL-KDD-completo.csv', index = False)
