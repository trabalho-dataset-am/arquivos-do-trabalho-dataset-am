# %% [markdown]
# ![logoIC_UFF.jpg](data:image/jpeg;base64,...)
#
#
#
# ---
#
#
# # **Atividade com Dataset escolhido [Pré-processamento do Dataset]**
# **Alunos**:
# Augusto Parisot de Gusmão Neto e Marcelo Marques da Rocha

# %%
import pandas as pd
import os
from google.colab import drive
import seaborn as sns
import matplotlib.pyplot as plt
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
labels = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate',
'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count',
'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate',
'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class', 'desconhecido']

len(labels)
# Out:
# 43

# %% [markdown]
# ###**Importando a parte de treino do dataset e corrigindo a ausência dos rótulos das colunas**###

# %%
nsl_kdd_train = pd.read_csv('/content/drive/MyDrive/KDDTrain+.csv', names=labels)
nsl_kdd_train.shape
# Out:
# (125973, 43)

# %%
nsl_kdd_train
# Out:
#         duration protocol_type  ...    class desconhecido
# 0              0           tcp  ...   normal           20
# 1              0           udp  ...   normal           15
# 2              0           tcp  ...  neptune           19
# 3              0           tcp  ...   normal           21
# 4              0           tcp  ...   normal           21
# ...          ...           ...  ...      ...          ...
# 125968         0           tcp  ...  neptune           20
# 125969         8           udp  ...   normal           21
# 125970         0           tcp  ...   normal           18
# 125971         0           tcp  ...  neptune           20
# 125972         0           tcp  ...   normal           21
#
# [125973 rows x 43 columns]

# %% [markdown]
# ###**Importando a parte de teste do dataset e corrigindo a audência dos rótulos das colunas**###

# %%
nsl_kdd_test = pd.read_csv('/content/drive/MyDrive/KDDTest+.csv', names=labels)
nsl_kdd_test.shape
# Out:
# (22544, 43)

# %%
nsl_kdd_test
# Out:
#        duration protocol_type  ...    class desconhecido
# 0             0           tcp  ...  neptune           21
# 1             0           tcp  ...  neptune           21
# 2             2           tcp  ...   normal           21
# 3             0          icmp  ...    saint           15
# 4             1           tcp  ...    mscan           11
# ...         ...           ...  ...      ...          ...
# 22539         0           tcp  ...   normal           21
# 22540         0           tcp  ...   normal           21
# 22541         0           tcp  ...     back           15
# 22542         0           udp  ...   normal           21
# 22543         0           tcp  ...    mscan           14
#
# [22544 rows x 43 columns]

# %% [markdown]
# ###**Concatenando os datasets para análise**###

# %%
kdd_completo = pd.concat([nsl_kdd_train, nsl_kdd_test])
kdd_completo.shape
# Out:
# (148517, 43)

# %%
nsl_kdd_train.describe()
# Out:
#            duration     src_bytes  ...  dst_host_srv_rerror_rate   desconhecido
# count  125973.00000  1.259730e+05  ...             125973.000000  125973.000000
# mean      287.14465  4.556674e+04  ...                  0.120240      19.504060
# std      2604.51531  5.870331e+06  ...                  0.319459       2.291503
# min         0.00000  0.000000e+00  ...                  0.000000       0.000000
# 25%         0.00000  0.000000e+00  ...                  0.000000      18.000000
# 50%         0.00000  4.400000e+01  ...                  0.000000      20.000000
# 75%         0.00000  2.760000e+02  ...                  0.000000      21.000000
# max     42908.00000  1.379964e+09  ...                  1.000000      21.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# ###**Observando os tipos dos atributos e se existe algum elemento null (NaN)**###

# %%
nsl_kdd_train.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
#  12  num_compromised              125973 non-null  int64
#  13  root_shell                   125973 non-null  int64
#  14  su_attempted                 125973 non-null  int64
#  15  num_root                     125973 non-null  int64
#  16  num_file_creations           125973 non-null  int64
#  17  num_shells                   125973 non-null  int64
#  18  num_access_files             125973 non-null  int64
#  19  num_outbound_cmds            125973 non-null  int64
#  20  is_host_login                125973 non-null  int64
#  21  is_guest_login               125973 non-null  int64
#  22  count                        125973 non-null  int64
#  23  srv_count                    125973 non-null  int64
#  24  serror_rate                  125973 non-null  float64
#  25  srv_serror_rate              125973 non-null  float64
#  26  rerror_rate                  125973 non-null  float64
#  27  srv_rerror_rate              125973 non-null  float64
#  28  same_srv_rate                125973 non-null  float64
#  29  diff_srv_rate                125973 non-null  float64
#  30  srv_diff_host_rate           125973 non-null  float64
#  31  dst_host_count               125973 non-null  int64
#  32  dst_host_srv_count           125973 non-null  int64
#  33  dst_host_same_srv_rate       125973 non-null  float64
#  34  dst_host_diff_srv_rate       125973 non-null  float64
#  35  dst_host_same_src_port_rate  125973 non-null  float64
#  36  dst_host_srv_diff_host_rate  125973 non-null  float64
#  37  dst_host_serror_rate         125973 non-null  float64
#  38  dst_host_srv_serror_rate     125973 non-null  float64
#  39  dst_host_rerror_rate         125973 non-null  float64
#  40  dst_host_srv_rerror_rate     125973 non-null  float64
#  41  class                        125973 non-null  object
#  42  desconhecido                 125973 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 41.3+ MB

# %%
#sns.countplot(x='desconhecido', data=kdd_completo);
#sns.distplot(kdd_completo['desconhecido'], kde=False);
nsl_kdd_train['desconhecido'].hist()

# %% [markdown]
# ####**Verificando a distribuição dos eventos em class (normal e ataques)**###

# %%
plt.figure(figsize=(80,20))
sns.countplot(x='class', data=nsl_kdd_train);

# %%
# o gráfico não ajuda nesse caso, já que são muitos tipos de ataques e com frequências muito distintas
# melhor contar usando uma representação tabular
qtd = nsl_kdd_train['class'].value_counts()
print("Total de tipos de eventos no atributo class: ", len(qtd))
print("normal(sem ataque) e 39 tipos de ataque...\n")
print(qtd)
# Out:
# Total de tipos de eventos no atributo class:  23
# normal(sem ataque) e 39 tipos de ataque...
#
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: class, dtype: int64

# %% [markdown]
# ###**Observando a correlação entre os atributos**###

# %%
nsl_kdd_train.corr()
# Out:
#                              duration  ...  desconhecido
# duration                     1.000000  ...     -0.156311
# src_bytes                    0.070737  ...     -0.022592
# dst_bytes                    0.034878  ...     -0.018076
# land                        -0.001553  ...     -0.037038
# wrong_fragment              -0.009866  ...     -0.157130
# urgent                       0.003830  ...     -0.016411
# hot                          0.000705  ...     -0.160013
# num_failed_logins            0.009528  ...     -0.073178
# logged_in                   -0.064218  ...      0.269818
# num_compromised              0.042679  ...     -0.006101
# root_shell                   0.052791  ...     -0.061631
# su_attempted                 0.087183  ...     -0.024402
# num_root                     0.045519  ...     -0.005126
# num_file_creations           0.099116  ...     -0.035187
# num_shells                  -0.001593  ...     -0.029863
# num_access_files             0.070420  ...     -0.001921
# num_outbound_cmds                 NaN  ...           NaN
# is_host_login               -0.000258  ...     -0.003079
# is_guest_login               0.000440  ...     -0.114359
# count                       -0.079042  ...     -0.030698
# srv_count                   -0.039470  ...     -0.114944
# serror_rate                 -0.069873  ...      0.009049
# srv_serror_rate             -0.069510  ...      0.013219
# rerror_rate                  0.200682  ...     -0.104418
# srv_rerror_rate              0.199961  ...     -0.103983
# same_srv_rate                0.074681  ...     -0.016111
# diff_srv_rate               -0.013738  ...     -0.055575
# srv_diff_host_rate          -0.040158  ...     -0.044408
# dst_host_count               0.050570  ...      0.020445
# dst_host_srv_count          -0.109776  ...      0.273033
# dst_host_same_srv_rate      -0.116005  ...      0.126981
# dst_host_diff_srv_rate       0.254195  ...     -0.175570
# dst_host_same_src_port_rate  0.228737  ...     -0.341422
# dst_host_srv_diff_host_rate -0.026669  ...     -0.232510
# dst_host_serror_rate        -0.064948  ...      0.004644
# dst_host_srv_serror_rate    -0.064361  ...      0.016218
# dst_host_rerror_rate         0.173815  ...     -0.100885
# dst_host_srv_rerror_rate     0.199024  ...     -0.091662
# desconhecido                -0.156311  ...      1.000000
#
# [39 rows x 39 columns]

# %% [markdown]
# ###O atributo **num_outbound_cmds** possui todos os valores em zero

# %% [markdown]
# ###**Usando o mapa de calor para observar a correlação entre os atributos**

# %%
plt.figure(figsize=(30, 20))
sns.heatmap(nsl_kdd_train.corr(), annot=True);

# %%
nsl_kdd_train['num_outbound_cmds'].describe()
# Out:
# count    125973.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: num_outbound_cmds, dtype: float64

# %% [markdown]
# ##**Investigando a relação entre os tipos de ataque e os tipos de protocolos de rede**##
#
# * O gráfico a seguir nos mostra que a grande maioria dos tipos de ataque se aplicam sobre o protocolo tcp.

# %%
coluna = ['class', 'protocol_type']
kdd_classe = nsl_kdd_train.filter(items=coluna)
sns.relplot(x="protocol_type", y="class", hue="protocol_type", style="protocol_type", data=kdd_classe);

# %%
#observando os atributos do tipo object 
plt.figure(figsize=(8, 5))
sns.countplot(x='flag', data=kdd_completo);

# %%
#observando os atributos do tipo object 
sns.countplot(x='protocol_type', data=kdd_completo);

# %% [markdown]
# ###**O atributo "desconhecido" parece não ter relação com algo importante**

# %%
# eliminando o atributo desconhecido
nsl_kdd_train.drop(columns=['desconhecido'])
# Out:
#         duration protocol_type  ... dst_host_srv_rerror_rate    class
# 0              0           tcp  ...                     0.00   normal
# 1              0           udp  ...                     0.00   normal
# 2              0           tcp  ...                     0.00  neptune
# 3              0           tcp  ...                     0.01   normal
# 4              0           tcp  ...                     0.00   normal
# ...          ...           ...  ...                      ...      ...
# 125968         0           tcp  ...                     0.00  neptune
# 125969         8           udp  ...                     0.00   normal
# 125970         0           tcp  ...                     0.00   normal
# 125971         0           tcp  ...                     0.00  neptune
# 125972         0           tcp  ...                     0.00   normal
#
# [125973 rows x 42 columns]

# %%
# eliminando o atributo desconhecido
nsl_kdd_test.drop(columns=['desconhecido'])
# Out:
#        duration protocol_type  ... dst_host_srv_rerror_rate    class
# 0             0           tcp  ...                     1.00  neptune
# 1             0           tcp  ...                     1.00  neptune
# 2             2           tcp  ...                     0.00   normal
# 3             0          icmp  ...                     0.00    saint
# 4             1           tcp  ...                     0.71    mscan
# ...         ...           ...  ...                      ...      ...
# 22539         0           tcp  ...                     0.00   normal
# 22540         0           tcp  ...                     0.00   normal
# 22541         0           tcp  ...                     0.07     back
# 22542         0           udp  ...                     0.00   normal
# 22543         0           tcp  ...                     1.00    mscan
#
# [22544 rows x 42 columns]

# %% [markdown]
# ###**Exportando os datasets pré-processados para serem importados no MOA**###

# %%
nsl_kdd_train.to_csv(r'/content/drive/MyDrive/NSL-KDD-train42.csv', index = False)
nsl_kdd_test.to_csv(r'/content/drive/MyDrive/NSL-KDD-test42.csv', index = False)
